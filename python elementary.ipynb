# %% [markdown]
# # Project title
#
# ## Project title
#
# ###### Project title
#
# this is introduction to jupyter notebook
#
# ## My point in order list
#
# 1. point one
# 2. point two
# 3. point three
#
# ## My point in unorder list
#
# - point one
# - point two
# - point three
#
# ![IMG_8625.JPG](attachment:IMG_8625.JPG)
#
# $1/2hb$

# %%
# about to write my first python code
print('Hello World, i am writing python programming language')
# Out:
# Hello World, i am writing python programming language

# %% [markdown]
# # Variable and Iidentifier
#
# - In a python, Variable is an entity/object located on the computer memory
# - identifier is used to identify  variable
#
# ## Rules for naming vairable
# 1. Variable name should be descriptive
# 2. variable name can not start with a number, though, number can be find any where else
# 3. any special characters except underscore can not be used in naming variable
# 4. space can not be used to join words in naming variables, Used Underscore instead

# %%
first_name = "olaitan"
last_name = "kazeem"
age = 12

print("my name is ", first_name, last_name , "and i am ", age, "years old")
# Out:
# my name is  olaitan kazeem and i am  12 years old

# %%
first_name = input("please enter your first name ")
last_name =  input()
age = input("please enter your age ")
print("my name is ", first_name, last_name , "and i am ", age, "years old")
# Out:
# please enter your first name james
# olaitan
# please enter your age 44
# my name is  james olaitan and i am  44 years old

# %% [markdown]
# # Operator in python
# Operator is used to manipulate Oprand
# 1. Arithmetic Operator
# 2. Assignment Operator
# 3. Comparason Operator
# 4. Identity Operator
# 5. Membership Operator
# 6. Logical Operator
# 7. bitwise Operator

# %% [markdown]
# # Arithmetic

# %%
# addition(+)
a = 12
b = 10
c = a + b
print(c)
# Out:
# 22

# %%
# subtraction(-)
a = 12
b = 10
c = a - b
print(c)
# Out:
# 2

# %%
# Multiplication*+)
a = 12
b = 10
c = a * b
print(c)
# Out:
# 120

# %%
# division(/)
a = 12
b = 10
c = a / b
print(c)
# Out:
# 1.2

# %%
# power(**)
a = 16
b = 2
c = a ** b
print(c)
# Out:
# 256

# %%
# Modulus(%) : used to retuen the remainder of division
a = 10
b = 3
c = a % b
print(c)
# Out:
# 1

# %% [markdown]
# # Assignment Operator

# %%
# equal to (=)
name = "olaitan"
print(name)
# Out:
# olaitan

# %%
# increment(+=)
a = 10
a+=5   # increase the value of a by five
print(a)
# Out:
# 15

# %%
# decrement(-=)
a = 10
a-=3   # decrease the value of a by three
print(a)
# Out:
# 7

# %% [markdown]
# # Comparison Operator
# is used to compear variables, and it return boolean result

# %%
# eqaul equal to (==)
a = 4
b = 7
a== b  # check if a is the same as b
# Out:
# False

# %%
# eqaul equal to (==)
a = 4
b = 4
a== b  # check if a is the same as b
# Out:
# True

# %%
# greater than(>)
a = 4
b = 7
a > b  # check if a is greater than b
# Out:
# False

# %%
# greater  than or equal to (>=)
a = 7
b = 7
a >= b  # check if a is greater than or eqaul to b
# Out:
# True

# %%
# less than(<)
a = 4
b = 7
a < b  # check if a is lesser than b
# Out:
# True

# %%
# less than or equal to (<=)
a = 4
b = 7
a <= b  # check if a is lesser than b
# Out:
# True

# %% [markdown]
# # Identity operator
# is / is not

# %%
a = 2
b = 2
a is b
# Out:
# True

# %%
a is not b
# Out:
# False

# %% [markdown]
# # Membership Operator
#
# in / not in

# %%
a = [2, 5, 7,9] # list
2 in a   # check if 2 is a member os list a
# Out:
# True

# %%
a = [2, 5, 7,9] # list
10 in a   # check if 2 is a member os list a
# Out:
# False

# %%
a = [2, 5, 7,9] # list
10 not in a   # check if 2 is a member os list a
# Out:
# True

# %%
# Logical Operator
and/ or

# %%
a = 4
b =7
c =10

(a> b) and (b<c)
# Out:
# False

# %%
a = 4
b =7
c =10
(a> b) or (b<c)
# Out:
# True

# %% [markdown]
# # Data type in python
# 1. Basic data type
#     a. str
#
#     b number
#
# 2. Collection Data type
#     a. List
#
#     b. tuple
#
#     c. set
#
#     d. dictionary
#
# - mutable data type: are kind of data type that can be modify after declaration (list, set, dictionary)
# - immutable data type: are kind of data type that can not be modify after declaration (str, number, tuple)

# %%
pnp

ileit
wes
